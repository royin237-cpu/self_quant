# %%
 import baostock as bs
 import pandas as pd
 '''
 获取复权因子
 '''

# %%
lg = bs.login()
# 显示登陆返回信息
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success

# %%
rs_list = []
# 查询2020至2026年复权因子
rs_factor = bs.query_adjust_factor(code="sh.601886", start_date="2020-01-01", end_date="2026-03-20")

# %%
while (rs_factor.error_code == '0') & rs_factor.next():
    rs_list.append(rs_factor.get_row_data())
result_factor = pd.DataFrame(rs_list, columns=rs_factor.fields)
result_factor.tail(10)
# 打印输出
# print(result_factor)

# 结果集输出到csv文件
# result_factor.to_csv("F:\\self_quant\\data_test\\notebook\\adjust_factor_data.csv", encoding="gbk", index=False)

# # 登出系统
# bs.logout()
# Out:
#         code dividOperateDate foreAdjustFactor backAdjustFactor adjustFactor
# 0  sh.601886       2020-05-26         0.801618         2.385949     2.385949
# 1  sh.601886       2021-05-25         0.847459         2.522389     2.522389
# 2  sh.601886       2022-06-13         0.859940         2.559538     2.559538
# 3  sh.601886       2023-05-30         0.862058         2.565842     2.565842
# 4  sh.601886       2024-05-10         0.891181         2.652526     2.652526
# 5  sh.601886       2024-10-11         0.915486         2.724867     2.724867
# 6  sh.601886       2025-04-28         0.980185         2.917437     2.917437
# 7  sh.601886       2025-10-13         1.000000         2.976415     2.976415
